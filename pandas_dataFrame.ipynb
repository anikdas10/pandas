# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Creating DataFrame

# %%
# using lists

student_data = [
    [100, 80, 10],
    [90, 70, 7],
    [120, 100, 14],
    [80, 50, 2],
]

pd.DataFrame(student_data, columns=["IQ", "Marks", "Package"])
# Out:
#     IQ  Marks  Package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
# using dict
student_dict = {
    "name": ["Anik", "Deb", "Maruf", "Rahim"],
    "iq": [100, 90, 120, 80],
    "marks": [80, 70, 100, 50],
    "Package": [10, 7, 14, 2],
}

students = pd.DataFrame(student_dict)
students.duplicated().sum()
# Out:
# np.int64(0)

# %%
# using read_csv
movies = pd.read_csv("./movies_csv_file//BollywoodActorRanking.csv")
movies
# Out:
#      actorId         actorName  movieCount  ratingSum  normalizedMovieRank  \
# 0        373        Aamir Khan          11       1170              9.44862
# 1        374    Shah Rukh Khan          23       2000              7.55009
# 2        375       Salman Khan          36       2340              5.40217
# 3        376      Katrina Kaif          17       1640              8.48082
# 4        377  Deepika Padukone          16       1080              5.64674
# ..       ...               ...         ...        ...                  ...
# 296      669       Achint Kaur           4         80              1.00000
# 297      670   Yuvika Chaudhry           5        100              1.00000
# 298      671      Pankaj Berry           5        100              1.00000
# 299      672      Varun Dhawan           0          0                  NaN
# 300      673     Nargis Fakhri           0          0                  NaN
#
#      googleHits  normalizedGoogleRank  normalizedRating
# ...

# %%
ipl = pd.read_csv("./csv_file/Match_Info.csv")

# %% [markdown]
# DataFrame Attribute and Methods

# %%
movies.shape
ipl.shape
# Out:
# (1169, 14)

# %%
# dtype
ipl.dtypes
# Out:
# match_number        int64
# team1              object
# team2              object
# match_date         object
# toss_winner        object
# toss_decision      object
# result             object
# eliminator         object
# winner             object
# player_of_match    object
# venue              object
# city               object
# team1_players      object
# team2_players      object
# dtype: object

# %%
# index
ipl.index
# Out:
# RangeIndex(start=0, stop=1169, step=1)

# %%
# columns
ipl.columns
# Out:
# Index(['match_number', 'team1', 'team2', 'match_date', 'toss_winner',
#        'toss_decision', 'result', 'eliminator', 'winner', 'player_of_match',
#        'venue', 'city', 'team1_players', 'team2_players'],
#       dtype='object')

# %%
ipl.values
# Out:
# array([[829707, 'Chennai Super Kings', 'Delhi Daredevils', ...,
#         'Chennai',
#         'DR Smith, BB McCullum, SK Raina, F du Plessis, RA Jadeja, MS Dhoni, DJ Bravo, R Ashwin, MM Sharma, IC Pandey, A Nehra',
#         'MA Agarwal, CM Gautam, JA Morkel, SS Iyer, KM Jadhav, Yuvraj Singh, JP Duminy, NM Coulter-Nile, A Mishra, Imran Tahir, DJ Muthuswami'],
#        [1473449, 'Kolkata Knight Riders', 'Mumbai Indians', ...,
#         'Mumbai',
#         'Q de Kock, SP Narine, AM Rahane, A Raghuvanshi, VR Iyer, RK Singh, MK Pandey, AD Russell, Ramandeep Singh, Harshit Rana, SH Johnson, CV Varun',
#         'V Puthur, RG Sharma, RD Rickelton, WG Jacks, SA Yadav, Tilak Varma, HH Pandya, Naman Dhir, MJ Santner, DL Chahar, TA Boult, Ashwani Kumar'],
#        [548323, 'Kolkata Knight Riders', 'Kings XI Punjab', ...,
#         'Kolkata',
#         'JH Kallis, G Gambhir, MS Bisla, MK Tiwary, Shakib Al Hasan, YK Pathan, DB Das, RN ten Doeschate, R Bhatia, SP Narine, JD Unadkat',
# ...

# %%
ipl.head(10)
# Out:
#    match_number                        team1                team2  match_date  \
# 0        829707          Chennai Super Kings     Delhi Daredevils  2015-04-09
# 1       1473449        Kolkata Knight Riders       Mumbai Indians  2025-03-31
# 2        548323        Kolkata Knight Riders      Kings XI Punjab  2012-04-15
# 3        548381        Kolkata Knight Riders  Chennai Super Kings  2012-05-27
# 4       1359533                 Punjab Kings       Delhi Capitals  2023-05-13
# 5       1473471  Royal Challengers Bengaluru         Punjab Kings  2025-04-18
# 6        548307        Kolkata Knight Riders     Delhi Daredevils  2012-04-05
# 7        419128  Royal Challengers Bangalore     Delhi Daredevils  2010-03-25
# 8        598072               Mumbai Indians     Rajasthan Royals  2013-05-24
# 9        548320        Kolkata Knight Riders     Rajasthan Royals  2012-04-13
#
#                    toss_winner toss_decision result eliminator  \
# ...

# %%
movies.tail()
# Out:
#      actorId        actorName  movieCount  ratingSum  normalizedMovieRank  \
# 296      669      Achint Kaur           4         80                  1.0
# 297      670  Yuvika Chaudhry           5        100                  1.0
# 298      671     Pankaj Berry           5        100                  1.0
# 299      672     Varun Dhawan           0          0                  NaN
# 300      673    Nargis Fakhri           0          0                  NaN
#
#      googleHits  normalizedGoogleRank  normalizedRating
# 296           0                   NaN              1.00
# 297           0                   NaN              1.00
# 298           0                   NaN              1.00
# 299           0                   NaN              4.74
# 300           0                   NaN              4.80

# %%
# sample

movies.sample()
# Out:
#      actorId          actorName  movieCount  ratingSum  normalizedMovieRank  \
# 275      648  Makrand Deshpande           5        110              1.19565
#
#      googleHits  normalizedGoogleRank  normalizedRating
# 275           0                   NaN           1.11151

# %%
# describe
movies.describe()
# Out:
#           actorId  movieCount    ratingSum  normalizedMovieRank    googleHits  \
# count  301.000000  301.000000   301.000000           299.000000  3.010000e+02
# mean   523.000000   10.232558   419.136213             2.768970  3.741886e+05
# std     87.035433    8.508764   446.972689             1.626970  6.647169e+05
# min    373.000000    0.000000     0.000000             1.000000  0.000000e+00
# 25%    448.000000    5.000000   140.000000             1.489130  0.000000e+00
# 50%    523.000000    7.000000   260.000000             2.369570  7.640000e+04
# 75%    598.000000   12.000000   500.000000             3.621045  3.850000e+05
# max    673.000000   54.000000  2950.000000            10.000000  3.490000e+06
#
#        normalizedGoogleRank  normalizedRating
# count            189.000000        301.000000
# mean               2.533937          2.933339
# std                1.951501          1.747883
# min                1.000000          1.000000
# ...

# %%
# info

movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   actorId               301 non-null    int64
#  1   actorName             301 non-null    object
#  2   movieCount            301 non-null    int64
#  3   ratingSum             301 non-null    int64
#  4   normalizedMovieRank   299 non-null    float64
#  5   googleHits            301 non-null    int64
#  6   normalizedGoogleRank  189 non-null    float64
#  7   normalizedRating      301 non-null    float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 18.9+ KB

# %%
movies.isnull().sum()
# Out:
# actorId                   0
# actorName                 0
# movieCount                0
# ratingSum                 0
# normalizedMovieRank       2
# googleHits                0
# normalizedGoogleRank    112
# normalizedRating          0
# dtype: int64

# %%
# duplicated
ipl.duplicated()
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
# rename
print(students)
students.rename(columns={"marks": "percent", "Package": "lpa"}, inplace=True) # inplace used to change permanently
# Out:
#     iq  percent  lpa
# 0  100       80   10
# 1   90       70    7
# 2  120      100   14
# 3   80       50    2
# 4    0        0    0
# 5    0        0    0

# %% [markdown]
# Math Methods

# %%
# sum -> axis arguments
students.sum(axis=0)
# Out:
# iq         390
# percent    300
# lpa         33
# dtype: int64

# %%
students.mean()
# Out:
# iq         65.0
# percent    50.0
# lpa         5.5
# dtype: float64

# %%
students.median(axis=1)
# Out:
# 0     80.0
# 1     70.0
# 2    100.0
# 3     50.0
# 4      0.0
# 5      0.0
# dtype: float64

# %%
students.var()
# Out:
# iq         2710.0
# percent    1760.0
# lpa          33.5
# dtype: float64

# %% [markdown]
# Selecting cols from a DataFrame

# %%
# single cols
movie = pd.read_csv("./csv_file/movies.csv")
movie["movie_name"]
# Out:
# 0           Kill Bill Vol. 1
# 1               Pulp Fiction
# 2           Django Unchained
# 3       Inglourious Basterds
# 4                     Avatar
# 5                    Titanic
# 6                      Alien
# 7           A Beautiful Mind
# 8                  Apollo 13
# 9                 Armageddon
# 10                  The Rock
# 11               Transformer
# 12                  13 Hours
# 13                The Island
# 14             A Quiet Place
# 15                Hereditary
# 16                 Midsommar
# 17    Thor: Love and Thunder
# 18               Jojo Rabbit
# 19                       Boy
# 20             6 Underground
# Name: movie_name, dtype: object

# %%
ipl["venue"]
# Out:
# 0                         MA Chidambaram Stadium, Chepauk
# 1                                Wankhede Stadium, Mumbai
# 2                                            Eden Gardens
# 3                         MA Chidambaram Stadium, Chepauk
# 4                             Arun Jaitley Stadium, Delhi
#                               ...
# 1164                     M Chinnaswamy Stadium, Bengaluru
# 1165    Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 1166    Maharaja Yadavindra Singh International Cricke...
# 1167                   Rajiv Gandhi International Stadium
# 1168                                            Kingsmead
# Name: venue, Length: 1169, dtype: object

# %%
# multiple cols
movies[["actorName", "movieCount", "ratingSum"]]
# Out:
#             actorName  movieCount  ratingSum
# 0          Aamir Khan          11       1170
# 1      Shah Rukh Khan          23       2000
# 2         Salman Khan          36       2340
# 3        Katrina Kaif          17       1640
# 4    Deepika Padukone          16       1080
# ..                ...         ...        ...
# 296       Achint Kaur           4         80
# 297   Yuvika Chaudhry           5        100
# 298      Pankaj Berry           5        100
# 299      Varun Dhawan           0          0
# 300     Nargis Fakhri           0          0
#
# [301 rows x 3 columns]

# %%
ipl[["team1", "team2", "winner"]]
# Out:
#                             team1                        team2  \
# 0             Chennai Super Kings             Delhi Daredevils
# 1           Kolkata Knight Riders               Mumbai Indians
# 2           Kolkata Knight Riders              Kings XI Punjab
# 3           Kolkata Knight Riders          Chennai Super Kings
# 4                    Punjab Kings               Delhi Capitals
# ...                           ...                          ...
# 1164          Chennai Super Kings  Royal Challengers Bangalore
# 1165          Sunrisers Hyderabad               Delhi Capitals
# 1166             Rajasthan Royals                 Punjab Kings
# 1167          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1168  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                            winner
# 0             Chennai Super Kings
# 1                  Mumbai Indians
# 2                 Kings XI Punjab
# 3           Kolkata Knight Riders
# ...

# %% [markdown]
# Selecting rows from a DataFrame

# %%
students = students.set_index("name")

# %%
# iloc searches using index position
movies.iloc[1]
# Out:
# actorId                            374
# actorName               Shah Rukh Khan
# movieCount                          23
# ratingSum                         2000
# normalizedMovieRank            7.55009
# googleHits                     2670000
# normalizedGoogleRank           7.88458
# normalizedRating               9.22674
# Name: 1, dtype: object

# %%
# multiple rows
movies.iloc[[5, 16, 3]]
# Out:
#     actorId       actorName  movieCount  ratingSum  normalizedMovieRank  \
# 5       378  Hrithik Roshan          16       1120              5.89130
# 16      389   Farhan Akhtar           6        370              5.07609
# 3       376    Katrina Kaif          17       1640              8.48082
#
#     googleHits  normalizedGoogleRank  normalizedRating
# 5      2650000               7.83298           8.25194
# 16     1860000               5.79496           6.62579
# 3      2120000               6.46570           8.94852

# %%
# loc searches using index labels
students.loc["Anik":"Rahim"]
# Out:
#         iq  marks  Package
# name
# Anik   100     80       10
# Deb     90     70        7
# Maruf  120    100       14
# Rahim   80     50        2

# %%
students.loc[["Anik", "Deb"]]
# Out:
#        iq  marks  Package
# name
# Anik  100     80       10
# Deb    90     70        7

# %%
students.iloc[[0, 3]]
# Out:
#         iq  marks  Package
# name
# Anik   100     80       10
# Rahim   80     50        2

# %%
bpl = pd.read_csv("./bpl_match_data/BPL (2012-2025).csv")
bpl
# Out:
#       season     match_no         date            team_1  team_1_score  \
# 0    2011/12        Final  Feb 29 2012   Barisal Burners           140
# 1    2011/12          2nd  Feb 28 2012  Dhaka Gladiators           191
# 2    2011/12          1st  Feb 28 2012  Duronto Rajshahi           184
# 3    2011/12         29th  Feb 27 2012  Dhaka Gladiators           116
# 4    2011/12         28th  Feb 26 2012  Chittagong Kings           150
# ..       ...          ...          ...               ...           ...
# 476  2024/25         42nd   Feb 1 2025  Chittagong Kings           206
# 477  2024/25   Eliminator   Feb 3 2025    Rangpur Riders            85
# 478  2024/25  Qualifier 1   Feb 3 2025  Chittagong Kings           149
# 479  2024/25  Qualifier 2   Feb 5 2025     Khulna Tigers           163
# 480  2024/25        Final   Feb 7 2025  Chittagong Kings           194
#
#      team_1_wicket                team_2  team_2_score  team_2_wicket  \
# ...

# %% [markdown]
# Selecting both Rows and Cols

# %%
movies.iloc[0:3, 0:3]
# Out:
#    actorId       actorName  movieCount
# 0      373      Aamir Khan          11
# 1      374  Shah Rukh Khan          23
# 2      375     Salman Khan          36

# %%
movies.loc[0:2, "actorId":"movieCount"]
# Out:
#    actorId       actorName  movieCount
# 0      373      Aamir Khan          11
# 1      374  Shah Rukh Khan          23
# 2      375     Salman Khan          36
